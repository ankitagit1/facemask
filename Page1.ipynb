# %%
import cv2,time
import numpy as np
import matplotlib.pyplot as plt

# %%
capture = cv2.VideoCapture(0)

# %%
flage, img= capture.read()
print(img)
print(flage)
# Out:
# [[[ 71  56  73]
#   [ 72  55  80]
#   [ 71  52  86]
#   ...
#   [ 53  51  80]
#   [ 50  53  80]
#   [ 41  45  71]]
#
#  [[ 72  57  90]
#   [ 78  63  90]
#   [ 71  55  77]
#   ...
#   [ 54  52  81]
#   [ 46  49  76]
#   [ 39  42  69]]
#
#  [[ 71  62  90]
#   [ 73  62  89]
#   [ 70  58  84]
#   ...
#   [ 47  45  75]
#   [ 45  48  75]
#   [ 40  43  70]]
#
#  ...
#
#  [[107  89 118]
#   [107  89 118]
#   [106  88 117]
#   ...
#   [ 47  40  63]
#   [ 48  43  64]
#   [ 43  38  59]]
#
#  [[103  85 112]
#   [ 99  82 108]
#   [101  84 111]
#   ...
#   [ 46  38  64]
#   [ 46  38  64]
#   [ 45  37  63]]
#
#  [[ 98  80 107]
#   [ 99  82 108]
#   [ 98  80 107]
#   ...
#   [ 39  31  57]
#   [ 37  29  55]
#   [ 36  28  54]]]
# True

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img[0]
# Out:
# array([[71, 56, 73],
#        [72, 55, 80],
#        [71, 52, 86],
#        ...,
#        [53, 51, 80],
#        [50, 53, 80],
#        [41, 45, 71]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
capture.release()

# %%
cv2.imshow('result',img)
if cv2.waitKey(2) == 27:
        cv2.destroyAllWindows()

# %%
haar_data=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
haar_data.detectMultiScale(img)
# Out:
# array([[319, 242, 193, 193]], dtype=int32)

# %%
faces = haar_data.detectMultiScale(img)
for x,y,w,h in faces:
    cv2.rectangle(img,(x,y),(x+w , y+h),(255,0,255),4)
    face=img[y:y+h, x:x+w,:]
    face=cv2.resize(face,(50,50))
    cv2.imshow('result',img)
    if cv2.waitKey(2) == 27:
        
        cv2.destroyAllWindows()

# %%
#Creating training datset

# %%
#capture = cv2.VideoCapture(0)
#data =[]
#while True:
 #   flag , img =capture.read()
  #  if flag:
        #faces = haar_data.detectMultiScale(img)
        #for x,y,w,h in faces:
         #   cv2.rectangle(img, (x,y), (x+w , y+h), (255,0,255), 4)
          #  face = img[y:y+h , x:x+w , :]
           # face = cv2.resize(face, (50,50))
            #print(len(data))
            #if len(data) < 400:
             #   data.append(face)
            #cv2.imshow('result',img)
            #if cv2.waitKey(2) == 27 or len(data) >= 200:
             #   break
#cv2.destroyAllWindows()

# %%
#capture.release()

# %%
#np.save('without _mask.npy',data)
#np.save('with_mask.npy',data)
